# %%
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
# Load crime data set into pandas
state_economy = pd.read_csv("state_economy.csv")
state_economy.head()
# Out:
#   SQGDP2 Gross domestic product (GDP) by state 1/       Unnamed: 1 Unnamed: 2  \
# 0                  (Millions of current dollars)               NaN        NaN
# 1                    Bureau of Economic Analysis               NaN        NaN
# 2                                     State or DC              NaN        NaN
# 3                                         GeoFips          GeoName   LineCode
# 4                                               0  United States *          1
#
#            Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# 2                 NaN        NaN        NaN        NaN        NaN        NaN
# 3         Description    2005:Q1    2005:Q2    2005:Q3    2005:Q4    2006:Q1
# 4  All industry total   12761337   12910022   13142873   13332316   13603933
#
# ...

# %%
state_economy.columns = state_economy.iloc[3]
state_economy.head()
# Out:
# 3                         GeoFips          GeoName  LineCode  \
# 0  (Millions of current dollars)               NaN       NaN
# 1    Bureau of Economic Analysis               NaN       NaN
# 2                     State or DC              NaN       NaN
# 3                         GeoFips          GeoName  LineCode
# 4                               0  United States *         1
#
# 3         Description   2005:Q1   2005:Q2   2005:Q3   2005:Q4   2006:Q1  \
# 0                 NaN       NaN       NaN       NaN       NaN       NaN
# 1                 NaN       NaN       NaN       NaN       NaN       NaN
# 2                 NaN       NaN       NaN       NaN       NaN       NaN
# 3         Description   2005:Q1   2005:Q2   2005:Q3   2005:Q4   2006:Q1
# 4  All industry total  12761337  12910022  13142873  13332316  13603933
#
# 3   2006:Q2  ...   2017:Q2   2017:Q3   2017:Q4   2018:Q1   2018:Q2   2018:Q3  \
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df = state_economy.drop([0,1,2,3])

# %%
df1 = df.drop([1447,1448,1449,1450,1451])

# %%
df1 = df1.dropna()
df1.head(60)
# Out:
# 3  GeoFips          GeoName LineCode  \
# 4        0  United States *        1
# 5        0  United States *        2
# 6        0  United States *        3
# 7        0  United States *        6
# 8        0  United States *       10
# 9        0  United States *       11
# 10       0  United States *       12
# 11       0  United States *       13
# 12       0  United States *       25
# 13       0  United States *       34
# 14       0  United States *       35
# 15       0  United States *       36
# 16       0  United States *       45
# 17       0  United States *       51
# 18       0  United States *       56
# 19       0  United States *       60
# 20       0  United States *       64
# 21       0  United States *       65
# 22       0  United States *       69
# 23       0  United States *       70
# 24       0  United States *       76
# 25       0  United States *       79
# 26       0  United States *       82
# 27       0  United States *       83
# ...

# %%
df1['GeoName'].value_counts()
# Out:
# United States *         26
# Great Lakes             24
# Washington              24
# Colorado                24
# Virginia                24
# Oklahoma                24
# Connecticut             24
# Nevada                  24
# Plains                  24
# Rhode Island            24
# Ohio                    24
# Maine                   24
# Southwest               24
# Alaska                  24
# Idaho                   24
# Pennsylvania            24
# New England             24
# Michigan                24
# South Carolina          24
# North Carolina          24
# Arizona                 24
# Rocky Mountain          24
# Nebraska                24
# Mississippi             24
# Delaware                24
# California              24
# New Jersey              24
# Missouri                24
# Iowa                    24
# Massachusetts           24
# Texas                   24
# South Dakota            24
# Vermont                 24
# Utah                    24
# ...

# %%
us_total = df1.loc[(df1['GeoName'] == 'United States *') & (df1['LineCode'] == '1')]

# %%
df1 = df1[df1.GeoName != 'United States *']

# %%
df1 = df1[df1.GeoName != 'Far West']

# %%
df1 = df1[df1.GeoName != 'Rocky Mountain']

# %%
df1 = df1[df1.GeoName != 'Southwest']

# %%
df1 = df1[df1.GeoName != 'Southeast']

# %%
df1 = df1[df1.GeoName != 'Plains']

# %%
df1 = df1[df1.GeoName != 'Great Lakes']

# %%
df1 = df1[df1.GeoName != 'Mideast']

# %%
df1 = df1[df1.GeoName != 'New England']

# %%
df1['GeoName'].value_counts()
# Out:
# Massachusetts           24
# Wisconsin               24
# Oregon                  24
# Michigan                24
# North Dakota            24
# West Virginia           24
# Kentucky                24
# New Hampshire           24
# District of Columbia    24
# Hawaii                  24
# Indiana                 24
# Arizona                 24
# Nebraska                24
# Vermont                 24
# Montana                 24
# Mississippi             24
# Delaware                24
# California              24
# Kansas                  24
# New Jersey              24
# Texas                   24
# Missouri                24
# Iowa                    24
# Florida                 24
# North Carolina          24
# Pennsylvania            24
# Colorado                24
# Rhode Island            24
# South Dakota            24
# Utah                    24
# Tennessee               24
# Oklahoma                24
# Minnesota               24
# Arkansas                24
# ...

# %%
df1['GeoName'].nunique()
# Out:
# 51

# %%
df1 = df1[df1.LineCode != '1']

# %%
df1 = df1[df1.LineCode != '2']

# %%
df1 = df1[df1.LineCode != '13']

# %%
df1 = df1[df1.LineCode != '25']

# %%
df1.head(30)
# Out:
# 3  GeoFips  GeoName LineCode  \
# 33    1000  Alabama        3
# 34    1000  Alabama        6
# 35    1000  Alabama       10
# 36    1000  Alabama       11
# 37    1000  Alabama       12
# 40    1000  Alabama       34
# 41    1000  Alabama       35
# 42    1000  Alabama       36
# 43    1000  Alabama       45
# 44    1000  Alabama       51
# 45    1000  Alabama       56
# 46    1000  Alabama       60
# 47    1000  Alabama       64
# 48    1000  Alabama       65
# 49    1000  Alabama       69
# 50    1000  Alabama       70
# 51    1000  Alabama       76
# 52    1000  Alabama       79
# 53    1000  Alabama       82
# 54    1000  Alabama       83
# 57    2000   Alaska        3
# 58    2000   Alaska        6
# 59    2000   Alaska       10
# 60    2000   Alaska       11
# 61    2000   Alaska       12
# 64    2000   Alaska       34
# 65    2000   Alaska       35
# 66    2000   Alaska       36
# 67    2000   Alaska       45
# 68    2000   Alaska       51
#
# ...

# %%
df1['2005:Q1'].value_counts()
# Out:
# (D)        4
# 3586.6     2
# 7850.1     2
# 2490.4     2
# 731.8      2
#           ..
# 24537.2    1
# 6662.4     1
# 12873.1    1
# 10179      1
# 548.4      1
# Name: 2005:Q1, Length: 1010, dtype: int64

# %%
df1.loc[df1['2005:Q1'] == '(D)']
# Out:
# 3   GeoFips               GeoName LineCode  \
# 202   10000              Delaware        6
# 204   10000              Delaware       11
# 226   11000  District of Columbia        6
# 228   11000  District of Columbia       11
#
# 3                                          Description 2005:Q1 2005:Q2  \
# 202        Mining, quarrying, and oil and gas extra...     (D)     (D)
# 204                                       Construction     (D)     (D)
# 226        Mining, quarrying, and oil and gas extra...     (D)     (D)
# 228                                       Construction     (D)     (D)
#
# 3   2005:Q3 2005:Q4 2006:Q1 2006:Q2  ... 2017:Q2 2017:Q3 2017:Q4 2018:Q1  \
# 202     (D)     (D)     1.4     1.5  ...     (D)     (D)     (D)     (D)
# 204     (D)     (D)  2602.2  2524.8  ...    2654  2666.8  2727.5  2693.1
# 226     (D)     (D)       0       0  ...       0       0       0       0
# 228     (D)     (D)  1016.5  1126.1  ...     (D)     (D)     (D)  1646.4
#
# ...

# %%
tlist = [us_total, df1]
df1 = pd.concat(tlist)
df1.head(10)
# Out:
# 3  GeoFips          GeoName LineCode  \
# 4        0  United States *        1
# 33    1000          Alabama        3
# 34    1000          Alabama        6
# 35    1000          Alabama       10
# 36    1000          Alabama       11
# 37    1000          Alabama       12
# 40    1000          Alabama       34
# 41    1000          Alabama       35
# 42    1000          Alabama       36
# 43    1000          Alabama       45
#
# 3                                         Description   2005:Q1   2005:Q2  \
# 4                                  All industry total  12761337  12910022
# 33         Agriculture, forestry, fishing and hunting    2659.8    2643.4
# 34        Mining, quarrying, and oil and gas extra...    2421.4    2645.8
# 35                                          Utilities    3586.6      3730
# 36                                       Construction    7434.9    7605.6
# 37                                      Manufacturing   27768.3   27502.5
# ...

# %%
df1 = df1.replace('(D)', 0)

# %%
df1 = df1.astype({'2005:Q1':'float32',
                 '2005:Q2':'float32',
                 '2005:Q3':'float32',
                 '2005:Q4':'float32',
                 '2006:Q1':'float32',
                 '2006:Q2':'float32',
                 '2006:Q3':'float32',
                 '2006:Q4':'float32',
                 '2007:Q1':'float32',
                 '2007:Q2':'float32',
                 '2007:Q3':'float32',
                 '2007:Q4':'float32',
                  '2008:Q1':'float32',
                  '2008:Q2':'float32',
                  '2008:Q3':'float32',
                  '2008:Q4':'float32',
                  '2009:Q1':'float32',
                  '2009:Q2':'float32',
                  '2009:Q3':'float32',
                  '2009:Q4':'float32',
                  '2010:Q1':'float32',
                  '2010:Q2':'float32',
                  '2010:Q3':'float32',
                  '2010:Q4':'float32',
                  '2011:Q1':'float32',
                  '2011:Q2':'float32',
                  '2011:Q3':'float32',
                  '2011:Q4':'float32',
                  '2012:Q1':'float32',
                  '2012:Q2':'float32',
                  '2012:Q3':'float32',
                  '2012:Q4':'float32',
                  '2013:Q1':'float32',
                  '2013:Q2':'float32',
                  '2013:Q3':'float32',
                  '2013:Q4':'float32',
                  '2014:Q1':'float32',
                  '2014:Q2':'float32',
                  '2014:Q3':'float32',
                  '2014:Q4':'float32',
                  '2015:Q1':'float32',
                  '2015:Q2':'float32',
                  '2015:Q3':'float32',
                  '2015:Q4':'float32',
                  '2016:Q1':'float32',
                  '2016:Q2':'float32',
                  '2016:Q3':'float32',
                  '2016:Q4':'float32',
                  '2017:Q1':'float32',
                  '2017:Q2':'float32',
                  '2017:Q3':'float32',
                  '2017:Q4':'float32',
                  '2018:Q1':'float32',
                  '2018:Q2':'float32',
                  '2018:Q3':'float32',
                  '2018:Q4':'float32',
                  '2019:Q1':'float32',
                  '2019:Q2':'float32',
                  '2019:Q3':'float32'
                 })
df1
# Out:
# 3    GeoFips          GeoName LineCode  \
# 4          0  United States *        1
# 33      1000          Alabama        3
# 34      1000          Alabama        6
# 35      1000          Alabama       10
# 36      1000          Alabama       11
# ...      ...              ...      ...
# 1250   56000          Wyoming       70
# 1251   56000          Wyoming       76
# 1252   56000          Wyoming       79
# 1253   56000          Wyoming       82
# 1254   56000          Wyoming       83
#
# 3                                           Description       2005:Q1  \
# 4                                    All industry total  1.276134e+07
# 33           Agriculture, forestry, fishing and hunting  2.659800e+03
# 34          Mining, quarrying, and oil and gas extra...  2.421400e+03
# 35                                            Utilities  3.586600e+03
# 36                                         Construction  7.434900e+03
# ...

# %%
df1['2005 GDP'] = df1['2005:Q1'] + df1['2005:Q2'] + df1['2005:Q3'] + df1['2005:Q4']
df1['2006 GDP'] = df1['2006:Q1'] + df1['2006:Q2'] + df1['2006:Q3'] + df1['2006:Q4']
df1['2007 GDP'] = df1['2007:Q1'] + df1['2007:Q2'] + df1['2007:Q3'] + df1['2007:Q4']
df1['2008 GDP'] = df1['2008:Q1'] + df1['2008:Q2'] + df1['2008:Q3'] + df1['2008:Q4']
df1['2009 GDP'] = df1['2009:Q1'] + df1['2009:Q2'] + df1['2009:Q3'] + df1['2009:Q4']
df1['2010 GDP'] = df1['2010:Q1'] + df1['2010:Q2'] + df1['2010:Q3'] + df1['2010:Q4']
df1['2011 GDP'] = df1['2011:Q1'] + df1['2011:Q2'] + df1['2011:Q3'] + df1['2011:Q4']
df1['2012 GDP'] = df1['2012:Q1'] + df1['2012:Q2'] + df1['2012:Q3'] + df1['2012:Q4']
df1['2013 GDP'] = df1['2013:Q1'] + df1['2013:Q2'] + df1['2013:Q3'] + df1['2013:Q4']
df1['2014 GDP'] = df1['2014:Q1'] + df1['2014:Q2'] + df1['2014:Q3'] + df1['2014:Q4']
df1['2015 GDP'] = df1['2015:Q1'] + df1['2015:Q2'] + df1['2015:Q3'] + df1['2015:Q4']
df1['2016 GDP'] = df1['2016:Q1'] + df1['2016:Q2'] + df1['2016:Q3'] + df1['2016:Q4']
df1['2017 GDP'] = df1['2017:Q1'] + df1['2017:Q2'] + df1['2017:Q3'] + df1['2017:Q4']
df1['2018 GDP'] = df1['2018:Q1'] + df1['2018:Q2'] + df1['2018:Q3'] + df1['2018:Q4']

# %%
df1.head(20)
# Out:
# 3  GeoFips          GeoName LineCode  \
# 4        0  United States *        1
# 33    1000          Alabama        3
# 34    1000          Alabama        6
# 35    1000          Alabama       10
# 36    1000          Alabama       11
# 37    1000          Alabama       12
# 40    1000          Alabama       34
# 41    1000          Alabama       35
# 42    1000          Alabama       36
# 43    1000          Alabama       45
# 44    1000          Alabama       51
# 45    1000          Alabama       56
# 46    1000          Alabama       60
# 47    1000          Alabama       64
# 48    1000          Alabama       65
# 49    1000          Alabama       69
# 50    1000          Alabama       70
# 51    1000          Alabama       76
# 52    1000          Alabama       79
# 53    1000          Alabama       82
#
# 3                                         Description       2005:Q1  \
# 4                                  All industry total  1.276134e+07
# ...

# %%
df1 = df1.reset_index()

# %%
df1.to_csv('econ_clean_validation.csv')

# %%
df1.head()
# Out:
# 3  index GeoFips          GeoName LineCode  \
# 0      4       0  United States *        1
# 1     33    1000          Alabama        3
# 2     34    1000          Alabama        6
# 3     35    1000          Alabama       10
# 4     36    1000          Alabama       11
#
# 3                                        Description       2005:Q1  \
# 0                                 All industry total  1.276134e+07
# 1         Agriculture, forestry, fishing and hunting  2.659800e+03
# 2        Mining, quarrying, and oil and gas extra...  2.421400e+03
# 3                                          Utilities  3.586600e+03
# 4                                       Construction  7.434900e+03
#
# 3       2005:Q2       2005:Q3       2005:Q4       2006:Q1  ...      2009 GDP  \
# 0  1.291002e+07  1.314287e+07  1.333232e+07  1.360393e+07  ...  5.779573e+07
# 1  2.643400e+03  2.600600e+03  2.617700e+03  1.968900e+03  ...  7.663900e+03
# ...

# %%
df1 = df1.rename(columns={"GeoName":"State", "Description": "Industry"})

# %%
df1.head()
# Out:
# 3  index GeoFips            State LineCode  \
# 0      4       0  United States *        1
# 1     33    1000          Alabama        3
# 2     34    1000          Alabama        6
# 3     35    1000          Alabama       10
# 4     36    1000          Alabama       11
#
# 3                                           Industry       2005:Q1  \
# 0                                 All industry total  1.276134e+07
# 1         Agriculture, forestry, fishing and hunting  2.659800e+03
# 2        Mining, quarrying, and oil and gas extra...  2.421400e+03
# 3                                          Utilities  3.586600e+03
# 4                                       Construction  7.434900e+03
#
# 3       2005:Q2       2005:Q3       2005:Q4       2006:Q1  ...      2009 GDP  \
# 0  1.291002e+07  1.314287e+07  1.333232e+07  1.360393e+07  ...  5.779573e+07
# 1  2.643400e+03  2.600600e+03  2.617700e+03  1.968900e+03  ...  7.663900e+03
# ...

# %%
df1 = df1.drop(columns=['index','GeoFips','LineCode'])

# %%
df1.head()
# Out:
# 3            State                                           Industry  \
# 0  United States *                                 All industry total
# 1          Alabama         Agriculture, forestry, fishing and hunting
# 2          Alabama        Mining, quarrying, and oil and gas extra...
# 3          Alabama                                          Utilities
# 4          Alabama                                       Construction
#
# 3       2005:Q1       2005:Q2       2005:Q3       2005:Q4       2006:Q1  \
# 0  1.276134e+07  1.291002e+07  1.314287e+07  1.333232e+07  1.360393e+07
# 1  2.659800e+03  2.643400e+03  2.600600e+03  2.617700e+03  1.968900e+03
# 2  2.421400e+03  2.645800e+03  2.783300e+03  3.137700e+03  2.939100e+03
# 3  3.586600e+03  3.730000e+03  4.008800e+03  3.970700e+03  4.397900e+03
# 4  7.434900e+03  7.605600e+03  7.750800e+03  8.116400e+03  8.353500e+03
#
# 3       2006:Q2       2006:Q3       2006:Q4  ...      2009 GDP      2010 GDP  \
# ...

# %%
df1.drop(df1.iloc[:, 2:61], inplace = True, axis = 1)

# %%
df1.head()
# Out:
# 3            State                                           Industry  \
# 0  United States *                                 All industry total
# 1          Alabama         Agriculture, forestry, fishing and hunting
# 2          Alabama        Mining, quarrying, and oil and gas extra...
# 3          Alabama                                          Utilities
# 4          Alabama                                       Construction
#
# 3      2005 GDP      2006 GDP      2007 GDP      2008 GDP      2009 GDP  \
# 0  5.214655e+07  5.525844e+07  5.780744e+07  5.885138e+07  5.779573e+07
# 1  1.052150e+04  8.398900e+03  7.777200e+03  7.579800e+03  7.663900e+03
# 2  1.098820e+04  1.158120e+04  1.372790e+04  1.539620e+04  1.127920e+04
# 3  1.529610e+04  1.751530e+04  1.829800e+04  1.887740e+04  2.020990e+04
# 4  3.090770e+04  3.387860e+04  3.666270e+04  3.347170e+04  2.964740e+04
#
# 3      2010 GDP      2011 GDP      2012 GDP      2013 GDP      2014 GDP  \
# ...

# %%
df1 = df1.round()

# %%
clean_abs_df = df1.astype({
  '2005 GDP':'int32',
    '2006 GDP':'int32',
    '2007 GDP':'int32',
    '2008 GDP':'int32',
    '2009 GDP':'int32',
    '2010 GDP':'int32',
    '2011 GDP':'int32',
    '2012 GDP':'int32',
    '2013 GDP':'int32',
    '2014 GDP':'int32',
    '2015 GDP':'int32',
    '2016 GDP':'int32',
    '2017 GDP':'int32',
    '2018 GDP':'int32'
})

# %%
clean_abs_df.head()
# Out:
# 3            State                                           Industry  \
# 0  United States *                                 All industry total
# 1          Alabama         Agriculture, forestry, fishing and hunting
# 2          Alabama        Mining, quarrying, and oil and gas extra...
# 3          Alabama                                          Utilities
# 4          Alabama                                       Construction
#
# 3  2005 GDP  2006 GDP  2007 GDP  2008 GDP  2009 GDP  2010 GDP  2011 GDP  \
# 0  52146548  55258436  57807436  58851380  57795728  59968208  62170324
# 1     10522      8399      7777      7580      7664      7713      6364
# 2     10988     11581     13728     15396     11279     12138     11798
# 3     15296     17515     18298     18877     20210     22336     23283
# 4     30908     33879     36663     33472     29647     27238     26460
#
# 3  2012 GDP  2013 GDP  2014 GDP  2015 GDP  2016 GDP  2017 GDP  2018 GDP
# ...

# %%
clean_abs_df['Industry'] = clean_abs_df['Industry'].str.strip()

# %%
list(clean_abs_df.Industry)
# Out:
# ['All industry total',
#  'Agriculture, forestry, fishing and hunting',
#  'Mining, quarrying, and oil and gas extraction',
#  'Utilities',
#  'Construction',
#  'Manufacturing',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Finance and insurance',
#  'Real estate and rental and leasing',
#  'Professional, scientific, and technical services',
#  'Management of companies and enterprises',
#  'Administrative and support and waste management and remediation services',
#  'Educational services',
#  'Health care and social assistance',
#  'Arts, entertainment, and recreation',
#  'Accommodation and food services',
#  'Other services (except government and government enterprises)',
#  'Government and government enterprises',
#  'Agriculture, forestry, fishing and hunting',
#  'Mining, quarrying, and oil and gas extraction',
#  'Utilities',
#  'Construction',
#  'Manufacturing',
#  'Wholesale trade',
#  'Retail trade',
# ...

# %%
perc_df = clean_abs_df

# %%
def growth_perc(x,y):
    growth = (y - x)/x
    growth = growth*100
    growth = growth.round(2)
    return growth

def total_growth(a,b):
    tot_growth = (b-a)/a
    tot_growth = tot_growth*100
    tot_growth = tot_growth.round(2)
    return tot_growth

# %%
perc_df['2006 Growth %'] = growth_perc(perc_df['2005 GDP'],perc_df['2006 GDP'])
perc_df['2007 Growth %'] = growth_perc(perc_df['2006 GDP'],perc_df['2007 GDP'])
perc_df['2008 Growth %'] = growth_perc(perc_df['2007 GDP'],perc_df['2008 GDP'])
perc_df['2009 Growth %'] = growth_perc(perc_df['2008 GDP'],perc_df['2009 GDP'])
perc_df['2010 Growth %'] = growth_perc(perc_df['2009 GDP'],perc_df['2010 GDP'])
perc_df['2011 Growth %'] = growth_perc(perc_df['2010 GDP'],perc_df['2011 GDP'])
perc_df['2012 Growth %'] = growth_perc(perc_df['2011 GDP'],perc_df['2012 GDP'])
perc_df['2013 Growth %'] = growth_perc(perc_df['2012 GDP'],perc_df['2013 GDP'])
perc_df['2014 Growth %'] = growth_perc(perc_df['2013 GDP'],perc_df['2014 GDP'])
perc_df['2015 Growth %'] = growth_perc(perc_df['2014 GDP'],perc_df['2015 GDP'])
perc_df['2016 Growth %'] = growth_perc(perc_df['2015 GDP'],perc_df['2016 GDP'])
perc_df['2017 Growth %'] = growth_perc(perc_df['2016 GDP'],perc_df['2017 GDP'])
perc_df['2018 Growth %'] = growth_perc(perc_df['2017 GDP'],perc_df['2018 GDP'])
perc_df['2010-2018 Growth %'] = total_growth(perc_df['2010 GDP'],perc_df['2018 GDP'])

# %%
perc_df.head()
# Out:
# 3            State                                       Industry  2005 GDP  \
# 0  United States *                             All industry total  52146548
# 1          Alabama     Agriculture, forestry, fishing and hunting     10522
# 2          Alabama  Mining, quarrying, and oil and gas extraction     10988
# 3          Alabama                                      Utilities     15296
# 4          Alabama                                   Construction     30908
#
# 3  2006 GDP  2007 GDP  2008 GDP  2009 GDP  2010 GDP  2011 GDP  2012 GDP  ...  \
# 0  55258436  57807436  58851380  57795728  59968208  62170324  64788032  ...
# 1      8399      7777      7580      7664      7713      6364      7209  ...
# 2     11581     13728     15396     11279     12138     11798     11567  ...
# 3     17515     18298     18877     20210     22336     23283     22757  ...
# 4     33879     36663     33472     29647     27238     26460     27514  ...
#
# ...

# %%
#final clean dataframes
#find begin data analysis & charting

# %%
#questions to answer

# Which state grew the most in each industry from 2010-2018?
# Which state grew

# %%
industries = list(perc_df['Industry'].unique())
industries
# Out:
# ['All industry total',
#  'Agriculture, forestry, fishing and hunting',
#  'Mining, quarrying, and oil and gas extraction',
#  'Utilities',
#  'Construction',
#  'Manufacturing',
#  'Wholesale trade',
#  'Retail trade',
#  'Transportation and warehousing',
#  'Information',
#  'Finance and insurance',
#  'Real estate and rental and leasing',
#  'Professional, scientific, and technical services',
#  'Management of companies and enterprises',
#  'Administrative and support and waste management and remediation services',
#  'Educational services',
#  'Health care and social assistance',
#  'Arts, entertainment, and recreation',
#  'Accommodation and food services',
#  'Other services (except government and government enterprises)',
#  'Government and government enterprises']

# %%
govt_df = perc_df.loc[perc_df['Industry'] == 'Government and government enterprises']

# %%
govt_df.head()
# Out:
# 3         State                               Industry  2005 GDP  2006 GDP  \
# 20      Alabama  Government and government enterprises    100372    104836
# 40       Alaska  Government and government enterprises     30209     31642
# 60      Arizona  Government and government enterprises    118952    127301
# 80     Arkansas  Government and government enterprises     47043     50024
# 100  California  Government and government enterprises    859084    904825
#
# 3    2007 GDP  2008 GDP  2009 GDP  2010 GDP  2011 GDP  2012 GDP  ...  \
# 20     113430    117539    123486    125976    128211    128072  ...
# 40      32929     34214     36185     37308     39360     40997  ...
# 60     135239    142981    140179    145933    148071    151283  ...
# 80      51809     53639     55604     57581     58924     59736  ...
# 100    969547   1018035   1017920   1030718   1052515   1055771  ...
#
# 3    2010 Growth %  2011 Growth %  2012 Growth %  2013 Growth %  \
# ...

# %%
top_5_govt = govt_df.nlargest(5, '2010-2018 Growth %')
bot_5_govt = govt_df.nsmallest(5, '2010-2018 Growth %')
glist = [top_5_govt,bot_5_govt]
max_min_govt = pd.concat(glist)
max_min_govt.head(10)
# Out:
# 3             State                               Industry  2005 GDP  \
# 100      California  Government and government enterprises    859084
# 120        Colorado  Government and government enterprises    113445
# 820  South Carolina  Government and government enterprises     91848
# 960      Washington  Government and government enterprises    170173
# 900            Utah  Government and government enterprises     54524
# 360        Kentucky  Government and government enterprises     81527
# 380       Louisiana  Government and government enterprises     89450
# 600   New Hampshire  Government and government enterprises     26349
# 980   West Virginia  Government and government enterprises     36543
# 620      New Jersey  Government and government enterprises    198805
#
# 3    2006 GDP  2007 GDP  2008 GDP  2009 GDP  2010 GDP  2011 GDP  2012 GDP  \
# 100    904825    969547   1018035   1017920   1030718   1052515   1055771
# ...

# %%
#construction
#retail trade
#real estate and rental and leasing
#Educational services
#Health care and social assistance
#Accommodation and food services
#Government and government enterprises

# %%
acom_df = perc_df.loc[perc_df['Industry'] == 'Accommodation and food services']
top_5_acom = acom_df.nlargest(5, '2010-2018 Growth %')
bot_5_acom = acom_df.nsmallest(5, '2010-2018 Growth %')
alist = [top_5_acom,bot_5_acom]
max_min_acom = pd.concat(alist)
max_min_acom.head(10)
# Out:
# 3            State                         Industry  2005 GDP  2006 GDP  \
# 758         Oregon  Accommodation and food services     14841     15943
# 958     Washington  Accommodation and food services     30676     34448
# 258          Idaho  Accommodation and food services      4627      5049
# 98      California  Accommodation and food services    182460    195937
# 838   South Dakota  Accommodation and food services      3817      4182
# 38          Alaska  Accommodation and food services      4137      4417
# 498    Mississippi  Accommodation and food services     13890     13500
# 738       Oklahoma  Accommodation and food services     14690     15704
# 578         Nevada  Accommodation and food services     71800     75083
# 978  West Virginia  Accommodation and food services      6628      6847
#
# 3    2007 GDP  2008 GDP  2009 GDP  2010 GDP  2011 GDP  2012 GDP  ...  \
# 758     16907     16767     16505     17296     18432     20298  ...
# ...

# %%
health_df = perc_df.loc[perc_df['Industry'] == 'Health care and social assistance']
top_5_health = health_df.nlargest(5, '2010-2018 Growth %')
bot_5_health = health_df.nsmallest(5, '2010-2018 Growth %')
hlist = [top_5_health,bot_5_health]
max_min_health = pd.concat(hlist)
max_min_health.head(10)
# Out:
# 3            State                           Industry  2005 GDP  2006 GDP  \
# 896           Utah  Health care and social assistance     19287     21442
# 696   North Dakota  Health care and social assistance      8355      8839
# 956     Washington  Health care and social assistance     68022     72026
# 36          Alaska  Health care and social assistance      8337      8787
# 576         Nevada  Health care and social assistance     20387     21964
# 796   Rhode Island  Health care and social assistance     16658     17530
# 1016       Wyoming  Health care and social assistance      4050      4370
# 136    Connecticut  Health care and social assistance     56330     59413
# 496    Mississippi  Health care and social assistance     21818     23409
# 396          Maine  Health care and social assistance     19547     21019
#
# 3     2007 GDP  2008 GDP  2009 GDP  2010 GDP  2011 GDP  2012 GDP  ...  \
# 896      22592     24743     26648     27084     28403     29569  ...
# ...

# %%
# Create csv in case of 
#max_min_govt.to_csv('govt_df.csv')
#max_min_acom.to_csv('accommodation_df.csv')
#max_min_health.to_csv('healthcare_df.csv')

# %%
us_total = perc_df.loc[perc_df['State'] == 'United States *'] 
us_total.head()
# Out:
# 3            State            Industry  2005 GDP  2006 GDP  2007 GDP  \
# 0  United States *  All industry total  52146548  55258436  57807436
#
# 3  2008 GDP  2009 GDP  2010 GDP  2011 GDP  2012 GDP  ...  2010 Growth %  \
# 0  58851380  57795728  59968208  62170324  64788032  ...           3.76
#
# 3  2011 Growth %  2012 Growth %  2013 Growth %  2014 Growth %  2015 Growth %  \
# 0           3.67           4.21           3.63           4.42           3.98
#
# 3  2016 Growth %  2017 Growth %  2018 Growth %  2010-2018 Growth %
# 0           2.69            4.3           5.43               37.27
#
# [1 rows x 30 columns]

# %%
state_tot_df = clean_abs_df.iloc[0:0]

# %%
state_tot_df.head()
# Out:
# Empty DataFrame
# Columns: [State, Industry, 2005 GDP, 2006 GDP, 2007 GDP, 2008 GDP, 2009 GDP, 2010 GDP, 2011 GDP, 2012 GDP, 2013 GDP, 2014 GDP, 2015 GDP, 2016 GDP, 2017 GDP, 2018 GDP, 2006 Growth %, 2007 Growth %, 2008 Growth %, 2009 Growth %, 2010 Growth %, 2011 Growth %, 2012 Growth %, 2013 Growth %, 2014 Growth %, 2015 Growth %, 2016 Growth %, 2017 Growth %, 2018 Growth %, 2010-2018 Growth %]
# Index: []
#
# [0 rows x 30 columns]

# %%
perc_df.to_csv('GDPbyState.csv')
