# %%
import csv
import pandas as pd

# %%
file = 'state_economy.csv'

# %%
base_econ = pd.read_csv(file)

# %%
base_econ.head(10)
# Out:
#   SQGDP2 Gross domestic product (GDP) by state 1/       Unnamed: 1 Unnamed: 2  \
# 0                  (Millions of current dollars)               NaN        NaN
# 1                    Bureau of Economic Analysis               NaN        NaN
# 2                                     State or DC              NaN        NaN
# 3                                         GeoFips          GeoName   LineCode
# 4                                               0  United States *          1
# 5                                               0  United States *          2
# 6                                               0  United States *          3
# 7                                               0  United States *          6
# 8                                               0  United States *         10
# 9                                               0  United States *         11
#
#                                           Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ...

# %%
base_econ.columns = base_econ.iloc[3]

# %%
base_econ.head(50)
# Out:
# 3                          GeoFips          GeoName  LineCode  \
# 0   (Millions of current dollars)               NaN       NaN
# 1     Bureau of Economic Analysis               NaN       NaN
# 2                      State or DC              NaN       NaN
# 3                          GeoFips          GeoName  LineCode
# 4                                0  United States *         1
# 5                                0  United States *         2
# 6                                0  United States *         3
# 7                                0  United States *         6
# 8                                0  United States *        10
# 9                                0  United States *        11
# 10                               0  United States *        12
# 11                               0  United States *        13
# 12                               0  United States *        25
# 13                               0  United States *        34
# ...

# %%
base_econ = base_econ.iloc(base_econ[[4:]])
# Out:
#   File "<ipython-input-25-26e8b68348cc>", line 1
#     base_econ = base_econ.iloc(base_econ[[4:]])
#                                            ^
# SyntaxError: invalid syntax

# %%
base_econ
